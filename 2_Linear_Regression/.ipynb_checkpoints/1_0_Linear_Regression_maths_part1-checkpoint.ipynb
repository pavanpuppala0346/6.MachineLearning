# %% [markdown]
# ### Linear Regression Simple Maths

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/2_Linear_Regression/linreg1.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=618x240 at 0x2DE968F84E0>

# %% [markdown]
# #### y = 2x+1
# - if x = 1  then y = 2(1)+1=3
# - x = 2  then y = 5
# - x =-1  then y = -2+1 = -1

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/2_Linear_Regression/linreg2.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=609x450 at 0x2DE9697CAC8>

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/2_Linear_Regression/linreg3.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=489x517 at 0x2DE969965F8>

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/2_Linear_Regression/linreg4.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=521x324 at 0x2DE96996A58>

# %% [markdown]
# #### More Ref: https://www.mathsisfun.com/algebra/linear-equations.html
# #### More Ref: https://www.mathsisfun.com/algebra/line-equation-2points.html

# %% [markdown]
# 1.What is regression?
#     - Regression: Predict a numerical outcome ("dependent variable(y)") from a set of inputs ("independent variables(x1, x2 ….xn").
# 2.Examples: Sample questions
#     - How many units will we sell? (Regression) (0 to inf)
#     - What price will the customer pay for our product? (Regression) (0 to Inf)
# 3.Linear Regression
#     - y = β + β1 x1 + β2 x2 + ...
#     - y is linearly related to each x
#     - Each x contributes additively to y
# 4.http://www.learnbymarketing.com/tutorials/linear-regression-by-hand-in-excel/
# 5. Linear regression assumptions.

# %% [markdown]
# #### For More: https://www.statisticssolutions.com/assumptions-of-linear-regression/
#     - Linear relationship
#     - Multivariate normality
#     - No or little multicollinearity
#     - No auto-correlation
#     - Homoscedasticity

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/2_Linear_Regression/linreg5.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=470x533 at 0x2DE96996B38>
