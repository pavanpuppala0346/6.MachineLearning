# %% [markdown]
# ### Minkowski distance
# - The Minkowski distance is a metric in a normed vector space which can be considered as a generalization of both the Euclidean distance(p==2) and the Manhattan distance(p==1).
# - Minkowski distance is typically used with p being 1 or 2, which correspond to the Manhattan distance and the Euclidean distance respectively

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/1_KNN_algorithm/knn.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=383x157 at 0x22072BF24E0>

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/1_KNN_algorithm/knn1.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=557x76 at 0x22072DDE390>

# %% [markdown]
# #### Find unknown sample quality based on known samples:
# - For above example calculate Euclidean distance and if K = 3 then find the label of unknown point ?
#     - Bad
#     - Good

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/1_KNN_algorithm/knn2.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=760x232 at 0x22072DDE4E0>

# %% [markdown]
# #### Find unknown flower name based on known flower names using MS excel
# - Take iris data set and explain from scratch

# %% [markdown]
# #### Importance of K/n_neighbors
# - if n_neighbors ==1 then unknown sample will be treated as red triangle
# - if n_neighbors ==2 then unknown sample will be treated as red triangle
# - if n_neighbors ==5 then unknown sample will be treated as blue square

# %%
from PIL import Image
Image.open("E:/code/6.MachineLearning/1_KNN_algorithm/knn3.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=468x415 at 0x22072DDE828>

# %% [markdown]
# #### Hamming distance
# - In information theory, the Hamming distance between two strings of equal length is the number of positions at which the corresponding symbols are different.
# - For Ref:   https://en.wikipedia.org/wiki/Hamming_distance

# %% [markdown]
# #### For More: https://scikit-learn.org/stable/modules/neighbors.html

# %% [markdown]
# #### In KNN argument algorithm, will not accept below value?
# - brute
# - KDtree
# - balltree
# - random tree

# %% [markdown]
# #### KNN is ?
# - non-parametric method
# - parametric method

# %% [markdown]
# #### Non-parametric statisics: https://en.wikipedia.org/wiki/Nonparametric_statistics#Applications_and_purpose

# %% [markdown]
# #### Parametric Statistics:    https://en.wikipedia.org/wiki/Parametric_statistics

# %% [markdown]
# https://www.youtube.com/watch?v=lDjdGnICiNY&ab_channel=It%27sYoStyle
