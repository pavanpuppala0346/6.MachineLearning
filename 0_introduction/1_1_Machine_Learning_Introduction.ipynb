# %% [markdown]
# # Machine Learning Introduction

# %% [markdown]
# ### What is algorithm/Estimator?
# - A process or set of rules to be followed in calculations especially by a computer.
#     - Ex1:- Add two numbers
#         - Accept two numbers
#         - Add the two numbers
#         - Return result
#     - Ex2: Converting kilos to grams

# %% [markdown]
# ### what is Machine Learning?
# 1. Two definitions of Machine Learning are offered by
#     - Arthur Samuel
#     - Tom Mitchell

# %% [markdown]
# ### Arthur Samuel
# - The field of study that gives computers the ability to learn without being explicitly programmed(line by line programmed)
# - This is an older and informal definition
# - For More:- [https://en.wikipedia.org/wiki/Arthur_Samuel](https://en.wikipedia.org/wiki/Arthur_Samuel)

# %% [markdown]
# ### Tom Mitchell
# - Provides a more modern definition known as ETP
# - A computer program is said to learn from <b>Experience E</b> with respect to some class of <b>Task T</b> and <b>Performance/accuracy measure P</b>
#     - Ex1: playing checkers.
#     - Ex2: identifying the mail whether genuine or fake

# %% [markdown]
# * E = the experience of playing many games of checkers
# * T = the task of playing checkers.
# * P = the probability that the program will win the game.
# [https://en.wikipedia.org/wiki/AlphaGo](https://en.wikipedia.org/wiki/AlphaGo)

# %% [markdown]
# ### Applications of ML:
# 1. In the past decade, machine learning has given us
#     - Self Driving Cars(identifying the symbols by using deep learning)
#     - Practical Speech Recognition(ALEXA)
#     - Effective Web Search(relative to particular search engine)
#     - Vastly improved understanding of the human genome
# 2. ML is the best way to make progress towards human-level Artificial intelligence(AI)

# %% [markdown]
# ### ML Types:
# <b>1.	Supervised learning(if we know ‘y’ target variable)</b>
#     - Classification (the values of y are limited/categorical)
#         - Let us observe pima_indians_diabetes
#         - let us observe iris data set
#     - Regression (the values of y are continuous)
#         - let us observe auto-mpg.csv
#         - let us observe hourly_wages.csv
# <b>2.	Unsupervised learning(if you do not y)</b>
#     - Clustering(groups)
#         - let us observe iris_with_out_y_labels.csv
# <b>3.	Reinforcement Learning</b>

# %%
from PIL import Image
Image.open('E:/code/6.MachineLearning/img/ml1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=711x558 at 0x1EA9DF4DB00>

# %% [markdown]
# #### What is Supervised Learning?
# - Supervised Learning is the one, where you can consider the learning is guided by a teacher. We have a dataset which acts as a teacher and its role is to train the model or the machine. Once the model gets trained it can start making a prediction or decision when new data is given to it.

# %% [markdown]
# #### What is Unsupervised Learning?
# - The model learns through observation and finds structures in the data. Once the model is given a dataset, it automatically finds patterns and relationships in the dataset by creating clusters in it. What it cannot do is add labels to the cluster, like it cannot say this a group of apples or mangoes, but it will separate all the apples from mangoes.
# - Suppose we presented images of apples, bananas and mangoes to the model, so what it does, based on some patterns and relationships it creates clusters and divides the dataset into those clusters. Now if a new data is fed to the model, it adds it to one of the created clusters.

# %% [markdown]
# #### What is Reinforcement Learning?
# It is the ability of an agent to interact with the environment and find out what is the best outcome. It follows the concept of hit and trial method. The agent is rewarded or penalized with a point for a correct or a wrong answer, and on the basis of the positive reward points gained the model trains itself. And again once trained it gets ready to predict the new data presented to it.

# %% [markdown]
# #### Uses Cases: https://www.edureka.co/blog/what-is-machine-learning/

# %% [markdown]
# - In a regression problem, we are trying to predict results within a continuous output, meaning that we are trying to map input variables to some continuous function. (y=a+b*x)
# - In a classification problem, we are instead trying to predict results in a discrete output. In other words, we are trying to map input variables into discrete categories.(yes / NO or Male /Female or bad,good,very good and excellent ,1/0 …etc)
# - unsupervised learning, in which the training data consists of a set of input vectors x without any corresponding target values
# - Suppose, you are the head of a rental store and wish to understand preferences of your costumers to scale up your business. Is it possible for you to look at details of each costumer and derive a unique business strategy for each one of them? Definitely not. But, what you can do is to cluster all of your costumers into say 10 groups based on their purchasing habits and use a separate strategy for costumers in each of these 10 groups. And this is what we call clustering

# %% [markdown]
# #### y=mx+c
# - where, y is dependent variable
#     - m is slope(b)
#     - x is independent variable
#     - c is constant(a)

# %%
from PIL import Image
Image.open('E:/code/6.MachineLearning/img/ml2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=287x286 at 0x1EA9DF4D9E8>

# %% [markdown]
# #### For More official: https://scikit-learn.org/stable/tutorial/basic/tutorial.html

# %% [markdown]
# ### Test Your Understanding

# %% [markdown]
# a. Given data about the size of houses on the real estate market, to predict their price. What type of ML needed?
# - Supervised Classification
# - Supervised Regression
# - UNSupervised

# %% [markdown]
# b. House "sells for more or less than the asking price". What type of ML needed?
# - Supervised Classification
# - Supervised Regression
# - UNSupervised

# %% [markdown]
# c. Given a patient with a tumor, we have to predict whether the tumor is malignant or benign. What type of ML needed?
# - Supervised Classification
# - Supervised Regression
# - UNSupervised

# %% [markdown]
# d. Given a picture of a person, we have to predict their age on the basis of the given picture. What type of ML needed?
# - Supervised Classification
# - Supervised Regression
# - UNSupervised

# %% [markdown]
# e. Finding homogenous subgroups within larger group based on the fact People have features such as income, education attainment and gender?
# - Supervised Classification
# - Supervised Regression
# - UnSupervised
